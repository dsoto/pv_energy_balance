# %% [markdown]
# # run_simulation
#
# This notebook runs the main simulation routine and displays the output.

# %%
# %pylab inline
import sys
sys.path.append('../src')
import simulation as sim
import pandas as p
import datetime as dt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/dsoto/anaconda/envs/py33/lib/python3.3/site-packages/pandas/core/daterange.py:23: FutureWarning: DateRange is deprecated, use DatetimeIndex instead
#   FutureWarning)

# %%
# define battery type with python dictionary
lead_dict = {'type' : 'lead acid',
             'cost' : 0.14,
             'battery_efficiency_curve' : {'output_power':[0, 1000],
                                           'efficiency':[0.75,   0.75]},
             'DOD' : 0.5,
             'life' : 2
             }

# %%
# call simulation routine
sim.run_simulation(lead_dict, inverter_type='typical', load_type='day', plot=True, verbose=True)
# Out:
# typical day lead acid         &0.59&0.76&1306&595\\
# battery cost 213.467150171
# battery npv 1305.96668151
# {'battery_cost': 213.46715017144962,
#  'battery_npv': 1305.9666815077171,
#  'battery_size_kWh': 0.76238267918374858,
#  'battery_type': 'lead acid',
#  'inverter_type': 'typical',
#  'load_type': 'day',
#  'panel_cost': 594.96271441744432,
#  'panel_peak_kW': 0.5949627144174443}
